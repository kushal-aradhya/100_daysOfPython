# %%
print("Hello Kushal!")
# Out:
# Hello Kushal!

# %%
name = "Kushal"
age = 19
height = 5.7
is_footballer = True

print("Name:", name)
print("Age:", age)
print("Height:", height)
print("Is Footballer?", is_footballer)
# Out:
# Name: Kushal
# Age: 19
# Height: 5.7
# Is Footballer? True

# %%
user_name = input("What's your name?")
print("Hello " + user_name + "!")
# Out:
# Hello Kushal Aradhya!

# %%
age = int(input("How old are you?"))

if age >= 18:
    print("You are an adult.")
elif age >= 13:
    print("You are a teenager.")
else:
    print("You are a minor.")
# Out:
# You are an adult.

# %%
num = 0
while num < 5:
    print("Number: ", num)
    num += 1
